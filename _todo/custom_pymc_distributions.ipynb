# %%
import numpy as np
import pymc3 as pm
import scipy as sp
import scipy.stats as st
from theano import tensor as tt
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn
seaborn.set_style("ticks")
import theano
import arviz as az

# %% [markdown]
# Implement own distribution

# %%
from pymc3.distributions.dist_math import bound, factln, binomln, betaln, logpow, random_choice
from pymc3.distributions.distribution import Discrete, draw_values, generate_samples

# %%
class Error(pm.Discrete):
    def __init__(self, mu, *args, **kwargs):
        super(Error, self).__init__(*args, **kwargs)
        self.mu = mu
        self.mode = self.mean = mu
            
    def random(self, point=None):                
        raise ValueError()

    def logp(self, value):              
        mu = self.mu
        log_prob = bound(
            logpow(mu, value) - factln(value) - mu,
            mu >= 0, value >= 0)        
        return tt.switch(tt.eq(mu, 0) * tt.eq(value, 0), 0, log_prob)

# %%
np.random.seed(23)
data1 = sp.stats.poisson.rvs(1, size=50)
data2 = sp.stats.poisson.rvs(10, size=50)
data3 = sp.stats.poisson.rvs(20, size=50)
data = sp.append(data1, sp.append(data2, data3))

# %%
fig, ax = plt.subplots(figsize=(12, 5))
plt.hist(data, color="black")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.title("Data", loc="left", size=20)
plt.show()

# %%
K = 5

# %%
def stick_breaking(beta):
    p = tt.concatenate([[1], tt.extra_ops.cumprod(1 - beta)[:-1]])
    w = beta * p
    w = w / w.sum()
    return w

# %%
with pm.Model() as model:    
    beta = pm.Beta('beta', 1, .5, shape=K)
    w = pm.Deterministic('w', stick_breaking(beta))
    mu = pm.Gamma("mu", 10, 1, shape=K)    
    
    comps = [
        Error.dist(mu=mu[i])    
        for i in range(K)
    ]
    like = pm.Mixture('x', w=w, comp_dists=comps, observed=data)

# %%
with model:    
    trace = pm.sample(2000, chains=1, cores=1)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [mu, beta]
# 100%|██████████| 2500/2500 [00:11<00:00, 215.12it/s]
# There were 17 divergences after tuning. Increase `target_accept` or reparameterize.
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %%
az.plot_posterior(trace, var_names='w');

# %%
az.plot_posterior(trace, var_names='mu');
# Out:
# /home/simon/miniconda3/envs/ml/lib/python3.6/site-packages/arviz/data/io_pymc3.py:56: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   chain_likelihoods.append(np.stack(log_like))

# %%
with model:
    svgd = pm.fit(300, method='svgd')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-c574428c2e0e> in <module>
#       1 with model:
# ----> 2     svgd = pm.fit(300, method='opvi')
#
# ~/miniconda3/envs/ml/lib/python3.6/site-packages/pymc3/variational/inference.py in fit(n, local_rv, method, model, random_seed, start, inf_kwargs, **kwargs)
#     799             raise KeyError('method should be one of %s '
#     800                            'or Inference instance' %
# --> 801                            set(_select.keys()))
#     802     elif isinstance(method, Inference):
#     803         inference = method
#
# KeyError: "method should be one of {'advi', 'asvgd', 'nfvi', 'fullrank_advi', 'svgd'} or Inference instance"

# %%
trace = svgd.sample(10000)

# %%
az.plot_trace(trace, var_names='w');
# Out:
# /home/simon/miniconda3/envs/ml/lib/python3.6/site-packages/arviz/data/io_pymc3.py:56: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   chain_likelihoods.append(np.stack(log_like))

# %%
az.plot_trace(trace, var_names='mu');
# Out:
# /home/simon/miniconda3/envs/ml/lib/python3.6/site-packages/arviz/data/io_pymc3.py:56: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   chain_likelihoods.append(np.stack(log_like))

# %%
class Error(pm.Discrete):
    def __init__(self, mu, *args, **kwargs):
        super(Error, self).__init__(*args, **kwargs)
        #self.theta = theta
        #self.alpha = alpha
        #self.beta = beta
        self.mu = mu
        self.mode = self.mean = mu
            
    def random(self, point=None):                
        raise ValueError()

    def logp(self, value):              
#         theta, alpha, beta = self.theta, self.alpha, self.beta        
#         data = value.data
#         logp = float(0)
#         for i in range(data.shape[1]):            
#             for el in data[:,i]:
#                 if el:
#                     logp += logpow(p, el) + logpow(1 - p, 1 - el)
#                     logp += tt.log(theta * (1 - beta) + (1 - theta) * alpha)
#                 else:
#                     logp += tt.log(theta * beta + (1 - theta) * (1 - alpha))        
#         return logp
        mu = self.mu
        log_prob = bound(
            logpow(mu, value) - factln(value) - mu,
            mu >= 0, value >= 0)
        # Return zero when mu and value are both zero
        return tt.switch(tt.eq(mu, 0) * tt.eq(value, 0), 0, log_prob)

# %%
N = 20 
P = 3

# %%
np.random.seed(23)
data1 = sp.stats.bernoulli.rvs(.1, size=N * P).reshape((N, P))
data2 = sp.stats.bernoulli.rvs(.5, size=N * P).reshape((N, P))
data3 = sp.stats.bernoulli.rvs(.9, size=N * P).reshape((N, P))
data = sp.row_stack((data1, data2, data3))

# %%
plt.figure(figsize=(12, 5))
plt.imshow(np.transpose(data), "Greys")
plt.axis("off")
plt.title("Data", loc="left")
plt.show()

# %%
def stick_breaking(beta):
    p = tt.concatenate([[1], tt.extra_ops.cumprod(1 - beta)[:-1]])
    return beta * p

# %%
def bmix_logp(comp, mus):
    def _logp(value):
        mus_comp = mus[comp, :]        
        pos = value * tt.log(mus_comp)
        neg = (1 - value) * tt.log((1-mus_comp))
        comb = pos + neg
        overall_sum = tt.sum(comb)
        return overall_sum
    return _logp

# %%
K = 10

with pm.Model() as model: 
    alpha = pm.Gamma('alpha', 1., 1.)
    beta = pm.Beta('beta', 1., alpha, shape=K)
    w = pm.Deterministic('w', stick_breaking(beta))
    
    mu = pm.Beta('mu', 1, 1, shape=K)
    obs = pm.Mixture('obs', w,  
                 pm.Bernoulli.dist(mu, shape=(P, K)),
                 shape=K, 
                 observed=data.reshape((N * 3, P, 1)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5dc7a65a6de1> in <module>
#       4     alpha = pm.Gamma('alpha', 1., 1.)
#       5     beta = pm.Beta('beta', 1., alpha, shape=K)
# ----> 6     w = pm.Deterministic('w', stick_breaking(beta))
#       7
#       8     mu = pm.Beta('mu', 1, 1, shape=K)
#
# NameError: name 'stick_breaking' is not defined

# %%
with model:
    step = pm.Metropolis()
    trace = pm.sample(1000, step=step, random_seed=23)
    ppc = pm.sample_posterior_predictive(trace)
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# CompoundStep
# >Metropolis: [mu]
# >Metropolis: [beta]
# >Metropolis: [alpha]
# ...
#   0%|          | 0/2000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-35527fdbc241> in <module>
#       2     step = pm.Metropolis()
#       3     trace = pm.sample(1000, step=step, random_seed=23)
# ----> 4     ppc = pm.sample_posterior_predictive(trace)
#
# ~/miniconda3/envs/ml/lib/python3.6/site-packages/pymc3/sampling.py in sample_posterior_predictive(trace, samples, model, vars, size, random_seed, progressbar)
#    1133                 param = trace[idx % len_trace]
#    1134
# -> 1135             values = draw_values(vars, point=param, size=size)
#    1136             for k, v in zip(vars, values):
#    1137                 ppc_trace[k.name].append(v)
#
# ...

# %%
az.plot_trace(trace);
# Out:
# /home/simon/miniconda3/envs/ml/lib/python3.6/site-packages/arviz/data/io_pymc3.py:56: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   chain_likelihoods.append(np.stack(log_like))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-7c3f6fe9d699> in <module>
# ----> 1 az.plot_trace(trace);
#
# ~/miniconda3/envs/ml/lib/python3.6/site-packages/arviz/plots/traceplot.py in plot_trace(data, var_names, coords, divergences, figsize, textsize, lines, combined, kde_kwargs, hist_kwargs, trace_kwargs)
#     148                 _histplot_op(axes[idx, 0], row, **hist_kwargs)
#     149             else:
# --> 150                 plot_kde(row, textsize=xt_labelsize, ax=axes[idx, 0], **kde_kwargs)
#     151
# ...

# %%
import scipy.stats

# %%
data = scipy.stats.multivariate_normal.rvs([1,2], 1, size= 2 * 10)
data.shape
# Out:
# (20, 2)

# %%
def bernoulli_mixture_loglh(mus, weights, K, N):
        def logp_(value):
            logps = []
            value_neg = 1 - value
            logmus = tt.log(mus)
            neglogmus = tt.log(1-mus)

            # N*K matrix of likelihood contributions from X_i with mu_k
            betas = tt.tensordot(value, logmus, axes=[1, 1]) + tt.tensordot(value_neg, neglogmus, axes=[1, 1])

            ## Form alphas, NxK matrix with the component weights included
            alphas = (betas + tt.log(weights)).T

            # Take LSE rowise to get N vector
            # and add alpha_cluster1 to get the total likelihood across all
            # components for each X_i
            lse_clust = pm.math.logsumexp(alphas - alphas[0, :], axis=0) + alphas[0,:]

            # Final overall sum
            return tt.sum(lse_clust)
        return logp_

# %%
K = 10

with pm.Model() as model: 
    alpha = pm.Gamma('alpha', 1., 1.)
    beta = pm.Beta('beta', 1., alpha, shape=K)
    w = pm.Deterministic('w', stick_breaking(beta))
    
    mu = pm.Beta('mu', 1, 1)
    obs = pm.DensityDist('obs', 
                         bernoulli_mixture_loglh(mu, w, K, N),
                         observed=data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-a3689e123e6a> in <module>
#       9     obs = pm.DensityDist('obs',
#      10                          bernoulli_mixture_loglh(mu, w, K, N),
# ---> 11                          observed=data)
#
# ~/miniconda3/envs/ml/lib/python3.6/site-packages/pymc3/distributions/distribution.py in __new__(cls, name, *args, **kwargs)
#      40             total_size = kwargs.pop('total_size', None)
#      41             dist = cls.dist(*args, **kwargs)
# ---> 42             return model.Var(name, dist, data, total_size)
#      43         else:
#      44             raise TypeError("Name needs to be a string but got: {}".format(name))
#
# ~/miniconda3/envs/ml/lib/python3.6/site-packages/pymc3/model.py in Var(self, name, dist, data, total_size)
#     837                 var = ObservedRV(name=name, data=data,
# ...

# %%
import pandas as pd

# %%
old_faithful_df = pd.read_csv(pm.get_data('old_faithful.csv'))
data = (old_faithful_df.waiting - old_faithful_df.waiting.mean()) / old_faithful_df.waiting.std()

# %%
N = old_faithful_df.shape[0]

K = 10

# %%
with pm.Model() as model2:
    alpha = pm.Gamma('alpha', 1., 1.)
    beta = pm.Beta('beta', 1., alpha, shape=K)
    w = pm.Deterministic('w', stick_breaking(beta))

    tau = pm.Gamma('tau', 1., 1., shape=K)
    lambda_ = pm.Uniform('lambda', 0, 5, shape=K)
    mu = pm.Normal('mu', 0, tau=lambda_ * tau, shape=K)
    
    obs = pm.NormalMixture('obs', w, mu, tau=lambda_ * tau, observed=data)

# %%
with model2:    
    trace = pm.sample(1000, random_seed=23)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [mu, lambda, tau, beta, alpha]
# Sampling 2 chains:   0%|          | 0/3000 [00:00<?, ?draws/s]/home/simon/miniconda3/envs/ml/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
#
# Bad initial energy, check any log probabilities that are inf or -inf, nan or very small:
# obs   -inf
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/simon/miniconda3/envs/ml/lib/python3.6/site-packages/pymc3/parallel_sampling.py", line 123, in _start_loop
#     point, stats = self._compute_point()
#   File "/home/simon/miniconda3/envs/ml/lib/python3.6/site-packages/pymc3/parallel_sampling.py", line 154, in _compute_point
# ...

# %%
az.plot_trace(trace, var_names=['w']);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-16a346864802> in <module>
# ----> 1 az.plot_trace(trace, var_names=['w']);
#
# ~/miniconda3/envs/ml/lib/python3.6/site-packages/arviz/plots/traceplot.py in plot_trace(data, var_names, coords, divergences, figsize, textsize, lines, combined, kde_kwargs, hist_kwargs, trace_kwargs)
#     148                 _histplot_op(axes[idx, 0], row, **hist_kwargs)
#     149             else:
# --> 150                 plot_kde(row, textsize=xt_labelsize, ax=axes[idx, 0], **kde_kwargs)
#     151
#     152         if value[0].dtype.kind == "i":
#
# ~/miniconda3/envs/ml/lib/python3.6/site-packages/arviz/plots/kdeplot.py in plot_kde(values, values2, cumulative, rug, label, bw, quantiles, rotated, contour, fill_last, textsize, plot_kwargs, fill_kwargs, rug_kwargs, contour_kwargs, ax, legend)
# ...
